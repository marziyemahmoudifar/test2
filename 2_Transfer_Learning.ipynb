# %% [markdown]
# <a href="https://colab.research.google.com/github/marziyemahmoudifar/test2/blob/new1/2_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# %matplotlib inline
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # **Make your fist experience with Tensorflow-Keras**
# Our goal is to use transfer learning to learn an accurate image classifier from a relatively small number of training samples. Generally speaking, transfer learning refers to the process of leveraging the knowledge learned in one model for the training of another model..

# %% [markdown]
# ## Loading Training and Validation Data
#
# we use the dataset [CalTech-101](http://www.vision.caltech.edu/Image_Datasets/Caltech101/), which contains around 9000 labeled images belonging to 101 object categories. However, we will exclude 5 of the categories which have the most images. This is in order to keep the class distribution fairly balanced (around 50-100) and constrained to a smaller number of images, around 2935.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import os
import cv2
import random
import numpy as np
from sklearn.model_selection import train_test_split

! pip install TensorBoardColab
from tensorflow.keras.models import Sequential,Model # Model type to be used
from tensorflow.keras.layers import Dense, Activation, Dropout# Make Fully connected (FC) layers
from tensorflow.keras.utils import to_categorical # NumPy related tools
from tensorflow.keras.callbacks import TensorBoard  #Visulization of Accuracy and loss
from tensorboardcolab import TensorBoardColab, TensorBoardColabCallback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
# Out:
# Collecting TensorBoardColab
#   Downloading tensorboardcolab-0.0.22.tar.gz (2.5 kB)
# Building wheels for collected packages: TensorBoardColab
#   Building wheel for TensorBoardColab (setup.py) ... done
#   Created wheel for TensorBoardColab: filename=tensorboardcolab-0.0.22-py3-none-any.whl size=3857 sha256=7fef542854d48a355c809a9f88c6743ca5f4191bc8f55d99cd79b07affcae688
#   Stored in directory: /root/.cache/pip/wheels/69/4e/4a/1c6c267395cb10edded1050df12af165d3254cfce324e80941
# Successfully built TensorBoardColab
# Installing collected packages: TensorBoardColab
# Successfully installed TensorBoardColab-0.0.22
# Using TensorFlow backend.

# %%
from google.colab import drive
root = '/content/gdrive/'
drive.mount( root )
# Out:
# Mounted at /content/gdrive/

# %%
# !unzip gdrive/My\ Drive/KFuji_RGB-DS_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: row data/BD11_inf_201710_138_pc.mat
#   inflating: row data/BD11_inf_201710_138_RGB.jpg
#   inflating: row data/BD11_sup_201710_004_pc.mat
#   inflating: row data/BD11_sup_201710_004_RGB.jpg
#   inflating: row data/BD11_sup_201710_007_pc.mat
#   inflating: row data/BD11_sup_201710_007_RGB.jpg
#   inflating: row data/BD11_sup_201710_010_pc.mat
#   inflating: row data/BD11_sup_201710_010_RGB.jpg
#   inflating: row data/BD11_sup_201710_013_pc.mat
#   inflating: row data/BD11_sup_201710_013_RGB.jpg
#   inflating: row data/BD11_sup_201710_037_pc.mat
#   inflating: row data/BD11_sup_201710_037_RGB.jpg
#   inflating: row data/BD11_sup_201710_043_pc.mat
#   inflating: row data/BD11_sup_201710_043_RGB.jpg
#   inflating: row data/BD11_sup_201710_046_pc.mat
#   inflating: row data/BD11_sup_201710_046_RGB.jpg
#   inflating: row data/BD11_sup_201710_049_pc.mat
#   inflating: row data/BD11_sup_201710_049_RGB.jpg
#   inflating: row data/BD11_sup_201710_055_pc.mat
#   inflating: row data/BD11_sup_201710_055_RGB.jpg
#   inflating: row data/BD11_sup_201710_064_pc.mat
#   inflating: row data/BD11_sup_201710_064_RGB.jpg
09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_inf_201711_182_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_009_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_012_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_015_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_024_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_027_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_042_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_054_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_057_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_060_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_063_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_069_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_072_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_090_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_093_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_096_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_099_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_102_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_150_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_165_09_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_01_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_02_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_03_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_04_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_05_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_06_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_07_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_08_RGB.xml
#   inflating: preprocessed data/square_annotations1/BD12_sup_201711_171_09_RGB.xml
#   inflating: README.txt

# %%
DATADIR = "kFuji_RGB-DS_dataset"
CATEGORIES = os.listdir()
print(CATEGORIES)
CATEGORIES = ['preprocessed data']
print(CATEGORIES)
# Out:
# ['.config', 'gdrive', 'LICENSE.txt', 'row data', 'preprocessed data', 'README.txt', 'sample_data']
# ['preprocessed data']

# %%
training_data = []
IMG_SIZE_H=224 # you need to set up a numerical value here. Useful to resize to normalize data size
IMG_SIZE_W=224 # you need to set up a numerical value here. Useful to resize to normalize data size
def create_training_data():
    for preprocessed_data in CATEGORIES:  # do plants and weeds

        path = os.path.join(DATADIR,preprocessed_data)  # create path to the labels
        class_num = CATEGORIES.index(preprocessed_data)  # get the classification  (0 or a 1). 0=plants 1=weeds

        for img in os.listdir(path):  # iterate over each image per plants and weeds
          if img.endswith('.jpg'):
            img_array = cv2.imread(os.path.join(path,img))  # convert to array 
            new_array = cv2.resize(img_array, (IMG_SIZE_H, IMG_SIZE_W))  # resize to normalize data size
            training_data.append([new_array, class_num])  # add this to our training_data

# %%
annotations_bbox = pd.read_csv(annotations_bbox_annotations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-95d4600bd211> in <module>()
# ----> 1 annotations_bbox = pd.read_csv(annotations_bbox_annotations)
#
# NameError: name 'pd' is not defined

# %%
create_training_data()  # Calling the function for reading images and labels
print(len(training_data)) # Printing the size of the database
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-7c1c5c9147e7> in <module>()
# ----> 1 create_training_data()  # Calling the function for reading images and labels
#       2 print(len(training_data)) # Printing the size of the database
#
# <ipython-input-25-34198bbf813a> in create_training_data()
#       8         class_num = CATEGORIES.index(preprocessed_data)  # get the classification  (0 or a 1). 0=plants 1=weeds
#       9
# ---> 10         for img in os.listdir(path):  # iterate over each image per plants and weeds
#      11           if img.endswith('.jpg'):
#      12             img_array = cv2.imread(os.path.join(path,img))  # convert to array
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kFuji_RGB-DS_dataset/preprocessed data'

# %% [markdown]
# Preparation of data for importing to Keras

# %%
random.shuffle(training_data)
X = []  # An Array for images
y = []  # An Array for labels

for features,label in training_data:   # Seperation of iamegs and labels
    X.append(features)
    y.append(label)
print(np.array(X).shape) # Print the size of the database
# Out:
# (2935, 224, 224, 3)

# %%
X = np.array(X).reshape(-1, IMG_SIZE_H, IMG_SIZE_W, 3)  # Reshape data in a form that is suitable for keras
print(X.shape) # Print the size of the database
# Out:
# (2935, 224, 224, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
# Display 3 images 
plt.subplot(131)
plt.imshow(X[0,:,:,:])
plt.axis("off")
plt.subplot(132)
plt.imshow(X[10,:,:,:])
plt.axis("off")
plt.subplot(133)
plt.imshow(X[100,:,:,:]) 
plt.axis("off")
# show the plot
plt.show()

# %% [markdown]
# # **Importing necessary Libraries**

# %% [markdown]
# ### First training a neural net from scratch
#
# Before doing the transfer learning, let's first build a neural network from scratch for doing classification on our dataset. This will give us a baseline to compare to our transfer-learned network later.
#
# The network we will construct contains 4 alternating convolutional and max-pooling layers. After the last pooling layer, we will attach a fully-connected layer with 256 neurons then finally a softmax classification layer for our classes.

# %%
# normalize data
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# build the network
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(5))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 222, 222, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 109, 109, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 52, 52, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 1,209,829
# Trainable params: 1,209,829
# Non-trainable params: 0
# _________________________________________________________________

# %%
tbcCNN=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://ff45-35-202-157-76.ngrok.io

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='auto') #Stop training when a monitored metric has stopped improving.

checkpoint_filepath = 'checkpointCNN.h5'
Model_check = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto') #Callback to save the Keras model or model weights at some frequency.

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X_train, y_train, 
          validation_data=(X_test, y_test),
          epochs=50, batch_size=32,
          verbose=1,
          callbacks=[TensorBoardColabCallback(tbcCNN),early_stop, Model_check])
# Out:
# Train on 2054 samples, validate on 881 samples
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorboardcolab/core.py:49: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Epoch 1/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.6728 - acc: 0.7402WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorboardcolab/callbacks.py:51: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0095 - acc: 0.9985 - val_loss: 0.1050 - val_acc: 0.9750
# Epoch 18/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.9990
# Epoch 00018: val_loss did not improve from 0.09693
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0979 - val_acc: 0.9739
# Epoch 19/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0055 - acc: 0.9990
# Epoch 00019: val_loss did not improve from 0.09693
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0054 - acc: 0.9990 - val_loss: 0.1445 - val_acc: 0.9682
# Epoch 20/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0103 - acc: 0.9980
# Epoch 00020: val_loss improved from 0.09693 to 0.09501, saving model to checkpointCNN.h5
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0103 - acc: 0.9981 - val_loss: 0.0950 - val_acc: 0.9739
# Epoch 21/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0075 - acc: 0.9985
# Epoch 00021: val_loss improved from 0.09501 to 0.09490, saving model to checkpointCNN.h5
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0075 - acc: 0.9985 - val_loss: 0.0949 - val_acc: 0.9784
# Epoch 22/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9990
# Epoch 00022: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0053 - acc: 0.9990 - val_loss: 0.1248 - val_acc: 0.9739
# Epoch 23/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0079 - acc: 0.9985
# Epoch 00023: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0079 - acc: 0.9985 - val_loss: 0.1000 - val_acc: 0.9773
# Epoch 24/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9966
# Epoch 00024: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0114 - acc: 0.9966 - val_loss: 0.3162 - val_acc: 0.9342
# Epoch 25/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0964 - acc: 0.9717
# Epoch 00025: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 4s 2ms/sample - loss: 0.0962 - acc: 0.9718 - val_loss: 0.1648 - val_acc: 0.9557
# Epoch 26/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0217 - acc: 0.9941
# Epoch 00026: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0217 - acc: 0.9942 - val_loss: 0.1112 - val_acc: 0.9671
# Epoch 27/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0215 - acc: 0.9922
# Epoch 00027: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0214 - acc: 0.9922 - val_loss: 0.1089 - val_acc: 0.9648
# Epoch 28/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0261 - acc: 0.9927
# Epoch 00028: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0261 - acc: 0.9927 - val_loss: 0.2294 - val_acc: 0.9353
# Epoch 29/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0201 - acc: 0.9946
# Epoch 00029: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0200 - acc: 0.9946 - val_loss: 0.1255 - val_acc: 0.9682
# Epoch 30/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9990
# Epoch 00030: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0052 - acc: 0.9990 - val_loss: 0.1098 - val_acc: 0.9750
# Epoch 31/50
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0076 - acc: 0.9990
# Epoch 00031: val_loss did not improve from 0.09490
# 2054/2054 [==============================] - 5s 2ms/sample - loss: 0.0076 - acc: 0.9990 - val_loss: 0.1517 - val_acc: 0.9614
# Epoch 00031: early stopping

# %% [markdown]
# **Evaluation and Prediction**
#
# We can use our model to make a prediction on new images.

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0) #Evaluation of the model on the test dataset
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 0.15165555163389166
# Test accuracy: 0.9614075

# %% [markdown]
# Finally, we see that we have achieved a (top-1) accuracy of around 97%. That's not too bad for 2935 images, considering that if we were to use a naive strategy of taking random guesses, we would have only gotten around 1% accuracy.
#
# ## Transfer learning by starting with existing network
#
# Now we can move on to the main strategy for training an image classifier on our small dataset: by starting with a larger and already trained network.
#
# To start, we will load the VGG16 from keras, which was trained on ImageNet and the weights saved online. If this is your first time loading VGG16, you'll need to wait a bit for the weights to download from the web. Once the network is loaded, we can again inspect the layers with the `summary()` method.

# %%
vgg = tf.keras.applications.VGG16(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 10s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Notice that VGG16 is _much_ bigger than the network we constructed earlier. It contains 13 convolutional layers and two fully connected layers at the end, and has over 138 million parameters, around 100 times as many parameters than the network we made above. Like our first network, the majority of the parameters are stored in the connections leading into the first fully-connected layer.
#
# VGG16 was made to solve ImageNet, and achieves a [8.8% top-5 error rate](https://github.com/jcjohnson/cnn-benchmarks), which means that 91.2% of test samples were classified correctly within the top 5 predictions for each image.
#
# In order to use this network for our task, we "remove" the final classification layer, the 1000-neuron softmax layer at the end, which corresponds to ImageNet, and instead replace it with a new softmax layer for our dataset, which contains 5 neurons in the case of our dataset.
#
# In terms of implementation, it's easier to simply create a copy of VGG from its input layer until the second to last layer, and then work with that, rather than modifying the VGG object directly. So technically we never "remove" anything, we just circumvent/ignore it. This can be done in the following way, by using the keras `Model` class to initialize a new model whose input layer is the same as VGG but whose output layer is our new softmax layer, called `new_classification_layer`. Note: although it appears we are duplicating this large network, internally Keras is actually just copying all the layers by reference, and thus we don't need to worry about overloading the memory.

# %%
# make a reference to VGG's input layer
inp = vgg.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(5, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(vgg.layers[-2].output)

# create a new network between inp and out
model_new = Model(inp, out)

# %% [markdown]
# We are going to retrain this network, `model_new` on our dataset and labels. But first, we need to freeze the weights and biases in all the layers in the network, except our new one at the end, with the expectation that the features that were learned in VGG should still be fairly relevant to the new image classification task. Not optimal, but most likely better than what we can train to in our limited dataset.
#
# By setting the `trainable` flag in each layer false (except our new classification layer), we ensure all the weights and biases in those layers remain fixed, and we simply train the weights in the one layer at the end. In some cases, it is desirable to *not* freeze all the pre-classification layers. If your dataset has enough samples, and doesn't resemble ImageNet very much, it might be advantageous to fine-tune some of the VGG layers along with the new classifier, or possibly even all of them. To do this, you can change the below code to make more of the layers trainable.
#
# In the case of CalTech-101, we will just do feature extraction, fearing that fine-tuning too much with this dataset may overfit. But maybe we are wrong? A good exercise would be to try out both, and compare the results.
#
# So we go ahead and freeze the layers, and compile the new model with exactly the same optimizer and loss function as in our first network, for the sake of a fair comparison. We then run `summary` again to look at the network's architecture.

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

model_new.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 134,281,029
# Trainable params: 20,485
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %% [markdown]
# Looking at the summary, we see the network is identical to the VGG model we instantiated earlier, except the last layer, formerly a 1000-neuron softmax, has been replaced by a new 5-neuron softmax. Additionally, we still have roughly 134 million weights, but now the vast majority of them are "non-trainable params" because we froze the layers they are contained in. We now only have 20,485 trainable parameters, which is actually less than 2% of the number of parameters needed to train the first model.
#
# As before, we go ahead and train the new model, using the same hyperparameters (batch size and number of epochs) as before, along with the same optimization algorithm. We also keep track of its history by tensorboard.

# %%
tbcTransfer=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# http://ff45-35-202-157-76.ngrok.io

# %%
checkpoint_filepath_transfer = 'checkpointTransfer.h5'
Model_check_transfer = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath_transfer, monitor='val_loss', verbose=1, save_best_only=True, mode='auto') #Callback to save the Keras model or model weights at some frequency.

# %%
model_new.fit(X_train, y_train, 
          validation_data=(X_test, y_test),
          epochs=100, batch_size=32,
          verbose=1,
          callbacks=[TensorBoardColabCallback(tbcTransfer),early_stop, Model_check_transfer])
# Out:
# Train on 2054 samples, validate on 881 samples
# Epoch 1/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.7449 - acc: 0.7783
# Epoch 00001: val_loss improved from inf to 0.30916, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 22s 11ms/sample - loss: 0.7439 - acc: 0.7790 - val_loss: 0.3092 - val_acc: 0.9330
# Epoch 2/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.2305 - acc: 0.9604
# Epoch 00002: val_loss improved from 0.30916 to 0.20489, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.2309 - acc: 0.9601 - val_loss: 0.2049 - val_acc: 0.9716
# Epoch 3/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.1608 - acc: 0.9673
# Epoch 00003: val_loss improved from 0.20489 to 0.14355, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.1605 - acc: 0.9674 - val_loss: 0.1435 - val_acc: 0.9762
# Epoch 4/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.1287 - acc: 0.9751
# Epoch 00004: val_loss improved from 0.14355 to 0.12436, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.1286 - acc: 0.9752 - val_loss: 0.1244 - val_acc: 0.9841
# Epoch 5/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0982 - acc: 0.9834
# Epoch 00005: val_loss improved from 0.12436 to 0.10944, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.0980 - acc: 0.9834 - val_loss: 0.1094 - val_acc: 0.9784
# Epoch 6/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0876 - acc: 0.9849
# Epoch 00006: val_loss improved from 0.10944 to 0.10409, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.0875 - acc: 0.9849 - val_loss: 0.1041 - val_acc: 0.9716
# Epoch 7/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0768 - acc: 0.9863
# Epoch 00007: val_loss improved from 0.10409 to 0.09939, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.0766 - acc: 0.9864 - val_loss: 0.0994 - val_acc: 0.9773
# Epoch 8/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0699 - acc: 0.9863
# Epoch 00008: val_loss improved from 0.09939 to 0.07289, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.0699 - acc: 0.9864 - val_loss: 0.0729 - val_acc: 0.9875
# Epoch 9/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0594 - acc: 0.9888
# Epoch 00009: val_loss did not improve from 0.07289
# 2054/2054 [==============================] - 17s 8ms/sample - loss: 0.0606 - acc: 0.9883 - val_loss: 0.0866 - val_acc: 0.9796
# Epoch 10/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0635 - acc: 0.9863
# Epoch 00010: val_loss did not improve from 0.07289
# 2054/2054 [==============================] - 17s 8ms/sample - loss: 0.0634 - acc: 0.9864 - val_loss: 0.1053 - val_acc: 0.9694
# Epoch 11/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0604 - acc: 0.9844
# Epoch 00011: val_loss improved from 0.07289 to 0.06895, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] -
saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 19s 9ms/sample - loss: 0.0251 - acc: 0.9966 - val_loss: 0.0425 - val_acc: 0.9852
# Epoch 28/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0244 - acc: 0.9966
# Epoch 00028: val_loss did not improve from 0.04249
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0243 - acc: 0.9966 - val_loss: 0.0527 - val_acc: 0.9830
# Epoch 29/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0227 - acc: 0.9976
# Epoch 00029: val_loss did not improve from 0.04249
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0240 - acc: 0.9971 - val_loss: 0.0730 - val_acc: 0.9739
# Epoch 30/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0536 - acc: 0.9844
# Epoch 00030: val_loss did not improve from 0.04249
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0535 - acc: 0.9844 - val_loss: 0.0469 - val_acc: 0.9841
# Epoch 31/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9976
# Epoch 00031: val_loss improved from 0.04249 to 0.04168, saving model to checkpointTransfer.h5
# 2054/2054 [==============================] - 20s 9ms/sample - loss: 0.0219 - acc: 0.9976 - val_loss: 0.0417 - val_acc: 0.9864
# Epoch 32/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0225 - acc: 0.9966
# Epoch 00032: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0224 - acc: 0.9966 - val_loss: 0.0533 - val_acc: 0.9807
# Epoch 33/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0264 - acc: 0.9922
# Epoch 00033: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0263 - acc: 0.9922 - val_loss: 0.0717 - val_acc: 0.9762
# Epoch 34/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0236 - acc: 0.9951
# Epoch 00034: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0236 - acc: 0.9951 - val_loss: 0.0463 - val_acc: 0.9875
# Epoch 35/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0186 - acc: 0.9971
# Epoch 00035: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0185 - acc: 0.9971 - val_loss: 0.0634 - val_acc: 0.9784
# Epoch 36/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0170 - acc: 0.9980
# Epoch 00036: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0170 - acc: 0.9981 - val_loss: 0.0475 - val_acc: 0.9852
# Epoch 37/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0158 - acc: 0.9985
# Epoch 00037: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0158 - acc: 0.9985 - val_loss: 0.0449 - val_acc: 0.9875
# Epoch 38/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0228 - acc: 0.9946
# Epoch 00038: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0227 - acc: 0.9946 - val_loss: 0.0528 - val_acc: 0.9830
# Epoch 39/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0199 - acc: 0.9980
# Epoch 00039: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0199 - acc: 0.9981 - val_loss: 0.0538 - val_acc: 0.9807
# Epoch 40/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0146 - acc: 0.9985
# Epoch 00040: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 17s 9ms/sample - loss: 0.0146 - acc: 0.9985 - val_loss: 0.0539 - val_acc: 0.9830
# Epoch 41/100
# 2048/2054 [============================>.] - ETA: 0s - loss: 0.0170 - acc: 0.9980
# Epoch 00041: val_loss did not improve from 0.04168
# 2054/2054 [==============================] - 18s 9ms/sample - loss: 0.0170 - acc: 0.9981 - val_loss: 0.0530 - val_acc: 0.9818
# Epoch 00041: early stopping

# %% [markdown]
# Our validation accuracy hovers close to 98% towards the end, which is more than 2% improvement on the original network trained from scratch.

# %% [markdown]
# **Evaluation and Prediction**
#
# We can use our model to make a prediction on new images.

# %%
model_New_load = tf.keras.models.load_model('checkpointTransfer.h5')
loss, accuracy = model_New_load.evaluate(X_test, y_test, verbose=0) #Evaluation of the model on the test dataset
print('Test loss:', loss)
print('Test accuracy:', accuracy)
